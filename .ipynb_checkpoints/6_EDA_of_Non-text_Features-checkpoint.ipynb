# %% [markdown]
# ## Exploratory Data Analysis:  Movie Ratings and Common Sense Metrics
# ### Import Non-text Features and convert to Pandas DataFrame for analysis

# %%
import numpy as np
import scipy.stats as stats
import pandas as pd
import seaborn as sns
import requests, json, csv, copy
import matplotlib.pyplot as plt
import math
import random

sns.set_style('darkgrid')

# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline

# %%
# Load json of movies_features_text
with open('data/movies_other_features.json') as json_file:  
    movies_other_features = json.load(json_file)

# %%
df = pd.DataFrame(movies_other_features)

# %%
### Eliminate spaces in front of MPAA ratings, to allow handling
df.MPAA_rating = df.MPAA_rating.map(lambda x: x.strip())

# %%
### Eliminate spaces in front of genre, to allow handling
df.genre = df.genre.map(lambda x: x.strip())

# %%
### Create ordinal list of MPAA movie ratings, to facilitate recommendations
mpaa_dict = {'G':0, 'PG':1, 'PG-13':2, 'R':3, 'NR':4, 'NC-17':5}

# %%
### Create new feature, MPAA_ordinal
df['MPAA_ordinal'] = df['MPAA_rating'].map(lambda x: mpaa_dict[x])

# %%
df[0:7]
# Out:
#    Consumerism  Drinking, Drugs & Smoking  Educational Value  Language  \
# 0          0.0                        3.0                NaN       4.0
# 1          0.0                        3.0                NaN       4.0
# 2          0.0                        2.0                NaN       0.0
# 3          0.0                        1.0                NaN       3.0
# 4          0.0                        4.0                NaN       4.0
# 5          1.0                        3.0                NaN       5.0
# 6          3.0                        1.0                NaN       2.0
#
#   MPAA_rating  Positive Messages  Positive Role Models & Representations  Sex  \
# 0           R                1.0                                     0.0  0.0
# 1           R                0.0                                     1.0  3.0
# 2           R                1.0                                     1.0  0.0
# 3           R                3.0                                     3.0  2.0
# 4           R                1.0                                     1.0  4.0
# 5          NR                1.0                                     1.0  3.0
# 6       PG-13                3.0                                     3.0  1.0
#
#    Sexy Stuff  Violence  Violence & Scariness  age             genre  \
# 0         NaN       4.0                   NaN   17          Thriller
# 1         NaN       4.0                   NaN   16           Western
# 2         NaN       3.0                   NaN   15          Thriller
# 3         NaN       3.0                   NaN   15          Thriller
# 4         NaN       2.0                   NaN   16            Comedy
# 5         NaN       2.0                   NaN   16            Comedy
# 6         NaN       4.0                   NaN   13  Action/Adventure
#
#    movie_id                               one_line_description  \
# 0         0  Solid drug war sequel has intense violence, la...
# 1         1  Unusual, uneven Western has violence, language...
# 2         2  Rapid-fire disturbing images in paranoid thril...
# 3         3  Well-made spy thriller has some war violence, ...
# 4         4   Indie road-trip dramedy has pot dealing/smoking.
# 5         5  Swearing, smoking, drinking in slight but appe...
# 6         6  Intense dino sequel has scary, jump-worthy vio...
#
#    overall_rating                           slug  \
# 0               3     sicario-day-of-the-soldado
# 1               3                         damsel
# 2               2                      distorted
# 3               4          the-catcher-was-a-spy
# 4               2                     boundaries
# 5               3  izzy-gets-the-fck-across-town
# 6               3  jurassic-world-fallen-kingdom
#
#                             title  MPAA_ordinal
# 0     Sicario: Day of the Soldado             3
# 1                          Damsel             3
# 2                       Distorted             3
# 3           The Catcher Was a Spy             3
# 4                      Boundaries             3
# 5  Izzy Gets the F*ck Across Town             4
# 6  Jurassic World: Fallen Kingdom             2

# %% [markdown]
# ### Exploratory Data Analysis:

# %%
# All movie rating features have at least one null value. Each feature is examined in detail
# to determine how to impute values while compromising our data the least.
def find_NaNs_left_to_clean(df=df):
    return df.loc[:, df.isnull().sum() != 0].isnull().sum()

# %%
find_NaNs_left_to_clean(df)
# Out:
# Consumerism                                 56
# Drinking, Drugs & Smoking                   35
# Educational Value                         7295
# Language                                    22
# Positive Messages                          376
# Positive Role Models & Representations    2147
# Sex                                       2038
# Sexy Stuff                                6617
# Violence                                  2031
# Violence & Scariness                      6600
# dtype: int64

# %%
# Visual inspection has lead me to believe that 0. can be safely imputed for the following
# features:
feature_zero = ['Consumerism', 'Drinking, Drugs & Smoking', 'Language', 'Positive Messages', 'Sex', 'Violence']

# %%
for feature in feature_zero:
    df[feature].fillna(0., inplace=True)

# %%
find_NaNs_left_to_clean(df)
# Out:
# Educational Value                         7295
# Positive Role Models & Representations    2147
# Sexy Stuff                                6617
# Violence & Scariness                      6600
# dtype: int64

# %% [markdown]
# ### Why Sexy Stuff and Sex? Violence and Violence and Scariness?
# #### Movies for Young Children are evaluated using different scales than those for teens:  Sexy Stuff, and Violence & Scariness are often used as scales for marital embraces or cartoon scariness as opposed to nudity or blood and gore in Sex and Violence ratings. Sexy Stuff, Violence & Scariness, and Educational Value are only present in movies recommended for children aged 8 and younger by Common Sense Media (see below). Consequently, boolean features were created to facilitate future data handling involving these features (e.g., 'is\_educational' is a 1 when any rating was given for 'Educational Value', etc.)
# #### Decision made to leave NaN's in these categories since there was no good way to impute them without destroying their reason for being.

# %%
### Create new column, ['is_educational'], that is 1 if any rating or 0 if NaN
df['is_educational'] = df['Educational Value'].notnull().map(int)

# %%
### Create new column, ['has_Sexy_Stuff'], that is 1 if any rating or 0 if NaN
df['has_Sexy_Stuff'] = df['Sexy Stuff'].notnull().map(int)

# %%
### Create new column, ['has_Violence_&_Scariness'], that is 1 if any rating or 0 if NaN
df['has_Violence_&_Scariness'] = df['Violence & Scariness'].notnull().map(int)

# %% [markdown]
# ### Minimum Age Recommendations and MPAA Ratings

# %%
fig = plt.figure(figsize=(7,4))
ax = fig.gca()

ax = sns.distplot(df['age'], bins=17, kde = False)

ax.set_title('Common Sense Media\'s\nMinimum Suggested Ages for Movies\n')
plt.show()

# %%
fig = plt.figure(figsize=(6,6))

ax1 = fig.add_subplot(321)
df[df['MPAA_rating']=='G']['age'].value_counts().sort_index().plot(kind='bar')
ax2 = fig.add_subplot(322)
df[df['MPAA_rating']=='PG']['age'].value_counts().sort_index().plot(kind='bar')
ax3 = fig.add_subplot(323)
df[df['MPAA_rating']=='PG-13']['age'].value_counts().sort_index().plot(kind='bar')
ax4 = fig.add_subplot(324)
df[df['MPAA_rating']=='R']['age'].value_counts().sort_index().plot(kind='bar')
ax5 = fig.add_subplot(325)
df[df['MPAA_rating']=='NR']['age'].value_counts().sort_index().plot(kind='bar')
ax6 = fig.add_subplot(326)
df[df['MPAA_rating']=='NC-17']['age'].value_counts().sort_index().plot(kind='bar')

ax1.title.set_text('Rated G')
ax2.title.set_text('Rated PG')
ax3.title.set_text('Rated PG-13')
ax4.title.set_text('Rated R')
ax5.title.set_text('Rated NR')
ax6.title.set_text('Rated NC-17')

plt.show()

fig.tight_layout();

# %%
df[df['MPAA_rating']=='G']['age'].mean()
# Out:
# 6.306930693069307

# %%
df[df['MPAA_rating']=='PG']['age'].mean()
# Out:
# 9.459352280237939

# %%
df[df['MPAA_rating']=='PG-13']['age'].mean()
# Out:
# 13.732133933033483

# %%
df[df['MPAA_rating']=='R']['age'].mean()
# Out:
# 16.71621034332899

# %%
df[df['MPAA_rating']=='NR']['age'].describe()
# Out:
# count    2197.000000
# mean       10.102868
# std         4.398250
# min         2.000000
# 25%         6.000000
# 50%        10.000000
# 75%        14.000000
# max        18.000000
# Name: age, dtype: float64

# %%
df[df['MPAA_rating']=='NC-17']['age'].mean()
# Out:
# 17.857142857142858

# %%
fig = plt.figure(figsize=(10,6))
ax1 = fig.add_subplot(221)
sns.boxplot(df['Sex'],
           orient='v',
           fliersize=8,
           linewidth=1.5,
           notch=True,
           saturation=0.5)
ax2 = fig.add_subplot(222)
sns.boxplot(df['Violence'],
           orient='v',
           fliersize=8,
           linewidth=1.5,
           notch=True,
           saturation=0.5)
ax3 = fig.add_subplot(223)
sns.boxplot(df['Language'],
           orient='v',
           fliersize=8,
           linewidth=1.5,
           notch=True,
           saturation=0.5)
ax4 = fig.add_subplot(224)
sns.boxplot(df['Positive Messages'],
           orient='v',
           fliersize=8,
           linewidth=1.5,
           notch=True,
           saturation=0.5)
ax1.title.set_text('Sex')
ax2.title.set_text('Violence')
ax3.title.set_text('Language')
ax4.title.set_text('Positive Messages')
plt.show()

fig.tight_layout();

# %%
df['Educational Value'].value_counts()
# Out:
# 0.0    519
# 1.0    431
# 2.0    200
# 3.0    104
# 4.0     55
# 5.0     21
# Name: Educational Value, dtype: int64

# %%
df['Educational Value'].value_counts().plot(kind='bar')

# %%
df['Drinking, Drugs & Smoking'].value_counts().sort_index().plot(kind='bar')

# %%
df['Language'].value_counts().sort_index().plot(kind='bar')

# %%
df['is_educational'].value_counts().plot(kind='bar')

# %%
df[df['is_educational'] ==1]['age'].describe()
# Out:
# count    1330.000000
# mean        6.009774
# std         1.586928
# min         2.000000
# 25%         5.000000
# 50%         6.000000
# 75%         7.000000
# max         8.000000
# Name: age, dtype: float64

# %% [markdown]
# ### Sexy Stuff

# %%
df['Sexy Stuff'].value_counts()
# Out:
# 0.0    1339
# 1.0     534
# 2.0     110
# 3.0      25
# Name: Sexy Stuff, dtype: int64

# %%
df['Sexy Stuff'].value_counts().plot(kind='bar')

# %%
df['Sex'].value_counts().sort_index().plot(kind='bar')

# %%
df[df['has_Sexy_Stuff'] ==1]['age'].describe()
# Out:
# count    2008.000000
# mean        6.110060
# std         1.609432
# min         2.000000
# 25%         5.000000
# 50%         6.000000
# 75%         8.000000
# max         8.000000
# Name: age, dtype: float64

# %% [markdown]
# ### Violence & Scariness

# %%
df['Violence & Scariness'].value_counts().sort_index().plot(kind='bar')

# %%
df['Violence'].value_counts().sort_index().plot(kind='bar')

# %%
df[df['has_Violence_&_Scariness'] ==1]['age'].describe()
# Out:
# count    2025.000000
# mean        6.098272
# std         1.617201
# min         2.000000
# 25%         5.000000
# 50%         6.000000
# 75%         8.000000
# max         8.000000
# Name: age, dtype: float64

# %% [markdown]
# #### Visual inspection of a subset of movies with a NaN for Sex and any value for Sexy Stuff revealed that Sexy Stuff does not even rise to a 1 on the Sex meter. These should also be set to zero. Likewise, nothing on the Violence & Scariness scale rose to even a 1 on the Violence metric, so these can safely be set to zero as well.

# %%
df['Sex'].fillna(0., inplace=True)
df['Violence'].fillna(0., inplace=True)

# %% [markdown]
# ### Positive Role Models & Representations

# %%
df['Positive Role Models & Representations'].value_counts().sort_index().plot(kind='bar')

# %%
df['Positive Messages'].value_counts().sort_index().plot(kind='bar')

# %%
### Create new column, ['has_Positive_Role_Models_&_Representations'],
### that is 1 if any rating or 0 if NaN
for movie in range(len(df)):
    if math.isnan(df['Positive Role Models & Representations'][movie]) == True:
        df.loc[movie, 'has_Positive_Role_Models_&_Representations'] = 0
    else:
        df.loc[movie, 'has_Positive_Role_Models_&_Representations']= 1

# %%
df[df['has_Positive_Role_Models_&_Representations'] ==1]['age'].describe()
# Out:
# count    6478.000000
# mean       12.116857
# std         4.142784
# min         2.000000
# 25%         9.000000
# 50%        13.000000
# 75%        16.000000
# max        18.000000
# Name: age, dtype: float64

# %%
df[df['Positive Role Models & Representations'].isnull()]
# Out:
#       Consumerism  Drinking, Drugs & Smoking  Educational Value  Language  \
# 335           3.0                        0.0                2.0       1.0
# 587           2.0                        0.0                0.0       0.0
# 2267          1.0                        3.0                NaN       3.0
# 2768          2.0                        0.0                0.0       1.0
# 4052          0.0                        0.0                NaN       0.0
# 4121          0.0                        3.0                NaN       0.0
# 4293          3.0                        3.0                NaN       0.0
# 4312          3.0                        3.0                NaN       0.0
# 4316          0.0                        0.0                NaN       0.0
# 4324          0.0                        0.0                NaN       0.0
# 4375          0.0                        3.0                NaN       0.0
# 4398          0.0                        3.0                NaN       3.0
# 4407          0.0                        0.0                NaN       0.0
# 4420          0.0                        2.0                NaN       2.0
# 4433          0.0                        3.0                NaN       3.0
# 4438          0.0                        0.0                NaN       3.0
# 4462          3.0                        1.0                NaN       3.0
# 4467          1.0                        0.0                3.0       0.0
# 4478          3.0                        2.0                NaN       3.0
# 4495          0.0                        3.0                NaN       0.0
# 4500          2.0                        0.0                NaN       1.0
# 4502          0.0                        0.0                NaN       4.0
# 4504          1.0                        2.0                NaN       2.0
# 4509          3.0                        3.0                NaN       3.0
# 4511          0.0                        0.0                NaN       0.0
# 4521          0.0                        3.0                NaN       0.0
# 4524          0.0                        0.0                NaN       0.0
# 4525          2.0                        2.0                NaN       2.0
# 4535          1.0                        2.0                NaN       4.0
# 4540          0.0                        2.0                NaN       4.0
# ...           ...                        ...                ...       ...
# 8558          0.0                        3.0                NaN       0.0
# 8559          0.0                        0.0                NaN       0.0
# 8560          0.0                        0.0                NaN       3.0
# 8562          0.0                        0.0                NaN       3.0
# 8563          0.0                        3.0                NaN       0.0
# 8564          0.0                        0.0                NaN       0.0
# 8565          0.0                        3.0                NaN       5.0
# 8569          0.0                        3.0                NaN       3.0
# 8570          0.0                        0.0                NaN       0.0
# 8572          0.0                        0.0                NaN       0.0
# 8574          0.0                        0.0                NaN       3.0
# 8575          0.0                        0.0                NaN       0.0
# 335   0.0         0.0       0.0                     ...
# 587   0.0         0.0       0.0                     ...
# 2267  3.0         NaN       4.0                     ...
# 2768  0.0         1.0       0.0                     ...
# 4052  0.0         NaN       3.0                     ...
# 4121  3.0         NaN       3.0                     ...
# 4293  4.0         NaN       0.0                     ...
# 4312  3.0         NaN       3.0                     ...
# 4316  0.0         NaN       1.0                     ...
# 4324  0.0         0.0       0.0                     ...
# 4375  3.0         NaN       0.0                     ...
# 4398  5.0         NaN       3.0                     ...
# 4407  0.0         0.0       0.0                     ...
# 4420  3.0         NaN       3.0                     ...
# 4433  3.0         NaN       1.0                     ...
# 4438  0.0         0.0       0.0                     ...
# 4462  3.0         NaN       3.0                     ...
# 4467  0.0         0.0       0.0                     ...
# 4478  3.0         NaN       2.0                     ...
# 4495  5.0         NaN       3.0                     ...
# 4500  0.0         NaN       3.0                     ...
# 4502  1.0         NaN       4.0                     ...
# 4504  3.0         NaN       1.0                     ...
# 4509  3.0         NaN       2.0                     ...
# 4511  0.0         0.0       0.0                     ...
# 4521  0.0         0.0       0.0                     ...
# 4524  0.0         0.0       0.0                     ...
# 4525  3.0         NaN       1.0                     ...
# 4535  3.0         NaN       2.0                     ...
# 4540  2.0         NaN       0.0                     ...
# ...   ...         ...       ...                     ...
# 8558  0.0         3.0       0.0                     ...
# 8559  0.0         0.0       0.0                     ...
# 8560  0.0         NaN       0.0                     ...
# 8562  3.0         NaN       3.0                     ...
# 8563  0.0         0.0       0.0                     ...
# 8564  0.0         NaN       3.0                     ...
# 8565  0.0         NaN       3.0                     ...
# 8569  3.0         NaN       3.0                     ...
# 8570  3.0         NaN       3.0                     ...
# 8572  0.0         0.0       0.0                     ...
# 8574  3.0         NaN       0.0                     ...
# 8575  0.0         0.0       0.0                     ...
# 8577  0.0         1.0       0.0                     ...
# 8578  3.0         NaN       3.0                     ...
# 8582  0.0         0.0       0.0                     ...
# 8583  3.0         NaN       3.0                     ...
# 8586  3.0         NaN       3.0                     ...
# 8589  0.0         NaN       3.0                     ...
# 8590  0.0         0.0       0.0                     ...
# 8591  3.0         NaN       3.0                     ...
# 8592  0.0         0.0       0.0                     ...
# 8595  0.0         0.0       0.0                     ...
# 8596  2.0         NaN       3.0                     ...
# 8602  0.0         NaN       3.0                     ...
# 8603  0.0         0.0       0.0                     ...
# 8604  0.0         NaN       0.0                     ...
# 8605  0.0         NaN       0.0                     ...
# 8606  0.0         NaN       0.0                     ...
# 8607  0.0         0.0       0.0                     ...
# 8614  0.0         0.0       0.0                     ...
#
#       movie_id                               one_line_description  \
# 335        438  More adventures of Kion and his Guard; cartoon...
# 587        691  Fine for fans; new viewers may be confused. So...
# 2267      2375   '60s Fellini classic has sex, drinking, suicide.
# 2768      2881  Toddler Bratz look unrealistic but promote tea...
# 4052      4167    This story of deaf musician is a real treasure.
# 4121      4236       Faithful adaptation of classic family story.
# 4293      4410  Frank, thoughtful look at teen sexuality and HIV.
# 4312      4429   Romcom is cute, but story is based on deception.
# 4316      4433  Powerful look at the impact of technology on o...
# 4324      4441  Stunning vision of the beautiful -- and fragil...
# 4375      4492     Good intro to corporate social responsibility.
# 4407              4                     youre-a-good-man-charlie-brown
# 4420              4                                 the-brothers-bloom
# 4433              4                                   all-the-way-home
# 4438              3                    au-pair-3-adventure-in-paradise
# 4462              3                              america-the-beautiful
# 4467              4                                        puppy-party
# 4478              3                                   four-christmases
# 4495              3                                          evergreen
# 4500              4                                           food-inc
# 4502              3                         the-taking-of-pelham-1-2-3
# 4504              2                                     whatever-works
# 4509              3                          nothing-like-the-holidays
# 4511              4                little-spirit-christmas-in-new-york
# 4521              3                                snow-2-brain-freeze
# 4524              2                         a-miser-brothers-christmas
# 4525              3                                   my-life-in-ruins
# 4535              2                                         management
# 4540              3                                         away-we-go
# ...             ...                                                ...
# 8558              5                  darby-ogill-and-the-little-people
# 8559              4                                 herbie-rides-again
# 8560              4                                   running-on-empty
# 8562              4                           the-best-of-roger-rabbit
# 8563              5                         disneys-sweetheart-stories
# 8564              5                        the-hunchback-of-notre-dame
# 8565              4                                          hairspray
# 8569              4                              the-thing-called-love
# 8570              4                                        hamlet-1991
# 8572              3                         the-pebble-and-the-penguin
# 8574              4                             the-accidental-tourist
# 8575              4                                 disneys-love-tales
# 8577              4                                               lili
# 8578              2                           robin-hood-men-in-tights
# 8582              5   the-adventures-of-curious-george-and-his-friends
# 8583              1                     the-incredible-shrinking-woman
# 8586              3                                         lean-on-me
# 8589              3                           i-was-a-teenage-werewolf
# 8590              4                                  jetsons-the-movie
# 8591              2                                white-men-cant-jump
# 8592              3                                         the-pirate
# 8595              4                              the-phantom-tollbooth
# 8596              4                                  a-dog-of-flanders
# 8602              5                               strangers-on-a-train
# 8603              5  the-shelly-t-turtle-show-ants-life-and-other-bugs
# 8604              4                              an-affair-to-remember
# 8605              4                                      eight-men-out
# 8606              1            journey-to-the-center-of-the-earth-1989
# 8607              3                                    big-top-pee-wee
# 8614              2                     the-strongest-man-in-the-world
#
#                                                   title  MPAA_ordinal  \
# 335                    The Lion Guard: The Rise of Scar             4
# 587                Digimon Adventure tri: Determination             4
# 2267                                      La Dolce Vita             4
# 2768                         Bratz Babyz Save Christmas             4
# 4052                             Playing from the Heart             4
# 4121                           A Tree Grows in Brooklyn             4
# 4293                                     Girl, Positive             4
# 4312                                     My Fake Fiance             4
# 4316       Digital Nation: Life on the Virtual Frontier             4
# 4324                                   Under the Sea 3D             0
# 4375                                      Major Barbara             4
# 4398                                       Little Ashes             3
# 4407                   You're a Good Man, Charlie Brown             4
# 4420                                 The Brothers Bloom             2
# 4433                                   All the Way Home             4
# 4438                   Au Pair 3: Adventure in Paradise             0
# 4462                              America the Beautiful             3
# 4467                                        Puppy Party             4
# 4478                                   Four Christmases             2
# 4495                                          Evergreen             2
# 4500                                         Food, Inc.             1
# 4502                         The Taking of Pelham 1 2 3             3
# 4504                                     Whatever Works             2
# 4509                          Nothing Like the Holidays             2
# 4511               Little Spirit: Christmas in New York             4
# 4521                               Snow 2: Brain Freeze             4
# 4524                        A Miser Brothers' Christmas             4
# 4525                                   My Life in Ruins             2
# 4535                                         Management             3
# 4540                                         Away We Go             3
# ...                                                 ...           ...
# 8558                 Darby O'Gill and the Little People             0
# 4495                                         0.0
# 4500                                         0.0
# 4502                                         0.0
# 4504                                         0.0
# 4509                                         0.0
# 4511                                         0.0
# 4521                                         0.0
# 4524                                         0.0
# 4525                                         0.0
# 4535                                         0.0
# 4540                                         0.0
# ...                                          ...
# 8558                                         0.0
# 8559                                         0.0
# 8560                                         0.0
# 8562                                         0.0
# 8563                                         0.0
# 8564                                         0.0
# 8565                                         0.0
# 8569                                         0.0
# 8570                                         0.0
# 8572                                         0.0
# 8574                                         0.0
# 8575                                         0.0
# 8577                                         0.0
# 8578                                         0.0
# 8582                                         0.0
# 8583                                         0.0
# 8586                                         0.0
# 8589                                         0.0
# 8590                                         0.0
# 8591                                         0.0
# 8592                                         0.0
# 8595                                         0.0
# 8596                                         0.0
# 8602                                         0.0
# 8603                                         0.0
# 8604                                         0.0
# 8605                                         0.0
# 8606                                         0.0
# 8607                                         0.0
# 8614                                         0.0
#
# [2147 rows x 23 columns]

# %% [markdown]
# #### No discernable pattern to null values in these movies for Positive Role Models & Representations. Decided to drop this variable entirely as including it may lead to false recommendations.

# %%
df.drop(columns='Positive Role Models & Representations', inplace=True)

# %%
df.drop(columns='has_Positive_Role_Models_&_Representations', inplace=True)

# %% [markdown]
# #### Save df for next notebook:  develop non-text filter to augment recommender system, indexing by movie title.

# %%
# movies_processed_nontext_features.set_index('title', inplace=True)

# %%
movies_processed_nontext_features = df

# %%
movies_processed_nontext_features.to_csv('data/movies_processed_nontext_features.csv')

# %%
movies_processed_nontext_features.head()
# Out:
#    Consumerism  Drinking, Drugs & Smoking  Educational Value  Language  \
# 0          0.0                        3.0                NaN       4.0
# 1          0.0                        3.0                NaN       4.0
# 2          0.0                        2.0                NaN       0.0
# 3          0.0                        1.0                NaN       3.0
# 4          0.0                        4.0                NaN       4.0
#
#   MPAA_rating  Positive Messages  Sex  Sexy Stuff  Violence  \
# 0           R                1.0  0.0         NaN       4.0
# 1           R                0.0  3.0         NaN       4.0
# 2           R                1.0  0.0         NaN       3.0
# 3           R                3.0  2.0         NaN       3.0
# 4           R                1.0  4.0         NaN       2.0
#
#    Violence & Scariness            ...                genre movie_id  \
# 0                   NaN            ...             Thriller        0
# 1                   NaN            ...              Western        1
# 2                   NaN            ...             Thriller        2
# 3                   NaN            ...             Thriller        3
# 4                   NaN            ...               Comedy        4
#
#                                 one_line_description overall_rating  \
# 0  Solid drug war sequel has intense violence, la...              3
# 1  Unusual, uneven Western has violence, language...              3
# 2  Rapid-fire disturbing images in paranoid thril...              2
# 3  Well-made spy thriller has some war violence, ...              4
# 4   Indie road-trip dramedy has pot dealing/smoking.              2
#
#                          slug                        title MPAA_ordinal  \
# 0  sicario-day-of-the-soldado  Sicario: Day of the Soldado            3
# 1                      damsel                       Damsel            3
# 2                   distorted                    Distorted            3
# 3       the-catcher-was-a-spy        The Catcher Was a Spy            3
# 4                  boundaries                   Boundaries            3
#
#    is_educational  has_Sexy_Stuff  has_Violence_&_Scariness
# 0               0               0                         0
# 1               0               0                         0
# 2               0               0                         0
# 3               0               0                         0
# 4               0               0                         0
#
# [5 rows x 21 columns]
