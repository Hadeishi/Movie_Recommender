# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
import requests, json, csv, copy, pickle
import math
import random
from sklearn.metrics.pairwise import cosine_similarity
from fuzzywuzzy import process

# Load json of movies_features_text
with open('data/movies_features_text.json') as json_file:
    movies_features_text = json.load(json_file)

# Load csv of movies_processed_nontext_features.csv
df = pd.read_csv('data/movies_processed_nontext_features.csv')

#Load pkl of similarity_matrix_tfidfvec_truncSVD1000.pkl
with open('data/similarity_matrix_tfidfvec_truncSVD1000.pkl', 'rb') as f:
    similarity_matrix_tfidfvec_truncSVD1000 = pickle.load(f)

def title_recommender(movie_name, movie_list, limit=3):
    results = process.extract(movie_name, movie_list, limit=limit)
    return results

def find_similar_movies():
    movie_name = input("Give me a movie title and I'll give you five titles you might also like:")
    for title in df['title']:
        if title == movie_name:
            sim_movies_text = similarity_matrix_tfidfvec_truncSVD1000[movie_name]
            print("Thanks! Here are my recommendations, along with review text similarity scores:")
            recommendations = pd.DataFrame(sim_movies_text.sort_values(ascending=False)[1:6])
            return recommendations
    limit = 3
    while title != movie_name:
        results = title_recommender(movie_name, df['title'], limit=limit)
        print("Sorry, that movie title isn't in my list. Did you mean", results, "?")
        movie_name = input("(I need the exact title, please...)")
        for title in df['title']:
            if title == movie_name:
                sim_movies_text = similarity_matrix_tfidfvec_truncSVD1000[movie_name]
                print("Thanks! Here are my recommendations, along with review text similarity scores:")
                recommendations = pd.DataFrame(sim_movies_text.sort_values(ascending=False)[1:6])
                return recommendations
            else:
                limit += 1
                if limit >= 10:
                    limit = 10

def find_all_similar_movies():
    movie_name = input("Give me a movie title and I'll give you five titles you might also like:")
    for title in df['title']:
        if title == movie_name:
            sim_movies_text = similarity_matrix_tfidfvec_truncSVD1000[movie_name]
            print("Thanks! Here are my recommendations, along with review text similarity scores:")
            recommendations = pd.DataFrame(sim_movies_text.sort_values(ascending=False)[1:8000])
            return recommendations
    limit = 3
    while title != movie_name:
        results = title_recommender(movie_name, df['title'], limit=limit)
        print("Sorry, that movie title isn't in my list. Did you mean", results, "?")
        movie_name = input("(I need the exact title, please...)")
        for title in df['title']:
            if title == movie_name:
                sim_movies_text = similarity_matrix_tfidfvec_truncSVD1000[movie_name]
                print("Thanks! Here are my movie recommendations:")
                recommendations = pd.DataFrame(sim_movies_text.sort_values(ascending=False)[1:8000])
                return recommendations
            else:
                limit += 1
                if limit >= 10:
                    limit = 10

def filter_movies_for_youngsters(parent_ratings, rec_movie_names, df):
    '''
    Will take in parent ratings, the indicies of recommended movies based on the single
    movie selection by the parent, and a df that contains nontext features of movies
    that are exclusively for youngsters (created by dropping all but movies that have
    a rating for Sexy Stuff, the most restrictive such screening variable). Function
    will filter the movie list according to family standards described by parents and
    generate the top 5 movies that meet parent expectations.
    '''
    _, wants_educational, prate_sexy_stuff, prate_violence_scariness, prate_consumerism, prate_drinking_drugs_smoking, prate_language, prate_positive_messages, prate_genre, prate_MPAA_rating = parent_ratings
    recs_filtered = []
    if wants_educational == 'y':
        want_educ = 1
    else:
        want_educ = 0

    movie_nums = get_index_nums(rec_movie_names)
    if len(movie_nums) == 0:
        print("Sorry, not enough movies in my list met your conditions. I recommend Toy Story!")
        return(4279)
    num_recs_filtered = []
    for num in movie_nums:
        if df.loc[num, 'is_educational'] == want_educ and df.loc[num, 'Sexy Stuff'] <= int(prate_sexy_stuff) and df.loc[num, 'Violence & Scariness'] <= int(prate_violence_scariness) and df.loc[num, 'Consumerism'] <= int(prate_consumerism) and df.loc[num, 'Drinking, Drugs & Smoking'] <= int(prate_drinking_drugs_smoking) and df.loc[num, 'Language'] <= int(prate_language) and df.loc[num, 'Positive Messages'] >= int(prate_positive_messages) and df.loc[num, 'genre'] == prate_genre and df.loc[num, 'MPAA_ordinal'] <= prate_MPAA_rating:
            num_recs_filtered.append(num)
        if len(num_recs_filtered) == 5:
            break
    if len(num_recs_filtered) < 5:
        print("Sorry, not enough movies in my list met your conditions. I recommend Toy Story!")
        return(4279)
    if len(num_recs_filtered) > 0:
        print("Here are your recommended movies:")
    recs_filtered = movie_nums_to_movies(num_recs_filtered)

    return recs_filtered

def filter_movies_for_tweens(parent_ratings, rec_movie_names, df):
    '''
    Will take in parent ratings, the indicies of recommended movies based on the single
    movie selection by the parent, and a df that contains nontext features of movies
    that are exclusively for youngsters (created by dropping all but movies that have
    a rating for Violence & Scariness, the most inclusive such screening variable). Function
    will filter the movie list according to family standards described by parents and
    generate the top 5 movies that meet parent expectations.
    '''
    _, prate_consumerism, prate_drinking_drugs_smoking, prate_language, prate_positive_messages, prate_sex, prate_violence, prate_genre, prate_MPAA_rating = parent_ratings
    
    movie_nums = get_index_nums(rec_movie_names)
    if len(movie_nums) == 0:
        print("Sorry, not enough movies in my list met your conditions. I recommend Back to the Future!")
        return(6357)
    num_recs_filtered = []
    for num in movie_nums:
        if df.loc[num, 'Consumerism'] <= int(prate_consumerism) and df.loc[num, 'Drinking, Drugs & Smoking'] <= int(prate_drinking_drugs_smoking) and df.loc[num, 'Language'] <= int(prate_language) and df.loc[num, 'Positive Messages'] >= int(prate_positive_messages) and df.loc[num, 'Sex'] >= int(prate_sex) and df.loc[num, 'Violence'] >= int(prate_violence) and df.loc[num, 'genre'] == prate_genre and df.loc[num, 'MPAA_ordinal'] <= prate_MPAA_rating:
            num_recs_filtered.append(num)
        if len(num_recs_filtered) == 5:
            break
    if len(num_recs_filtered) < 5:
        print("Sorry, not enough movies in my list met your conditions. I recommend Back to the Future!")
        return(6357)
    if len(num_recs_filtered) > 0:
        print("Here are your recommended movies:")
    recs_filtered = movie_nums_to_movies(num_recs_filtered)

    return recs_filtered

def get_index_nums(movie_titles):
    movie_nums = []
    for name in movie_titles:
        movie_nums.append(df.title[df.title==name].index.tolist()[0])
    return(movie_nums)

def movie_nums_to_movies(movie_nums):
    movie_names = [df['title'][num] for num in movie_nums]
    return(movie_names) 

def system_test(trials):
    rate_recs = []
    for trial in reversed(range(trials)):
        print("Thank you for trying out MovieRec4Parents(tm)! You have", trial+1, "tries to go.")
        recommendations = find_similar_movies()
        print(recommendations)
        rate_recs.append(recommendations)
        for rec in range(len(recommendations)):
            print("On a scale of 1-5, how good is recommendation", rec+1,"? If you don't know the movie, enter 0.)")
            rating = input()
            rate_recs.append((trial, rec+1, rating))
    print("You're done! I hope you enjoyed using MovieRec4Parents(tm). Tell your friends!")
    return rate_recs

def get_parent_ratings_first():
    print("Welcome to MovieRec4Parents! Let me ask you a few questions before we begin.")
    num_children, children_ages = get_num_children_and_ages()
    youngsters = age_checker(children_ages)
    if youngsters == 1:
        wants_educational, prate_sexy_stuff, prate_violence_scariness, prate_consumerism, prate_drinking_drugs_smoking, prate_language, prate_positive_messages, prate_genre, prate_MPAA_rating = get_parent_ratings_youngsters()
        parent_ratings = youngsters, wants_educational, prate_sexy_stuff, prate_violence_scariness, prate_consumerism, prate_drinking_drugs_smoking, prate_language, prate_positive_messages, prate_genre, prate_MPAA_rating

    else:
        prate_consumerism, prate_drinking_drugs_smoking, prate_language, prate_positive_messages, prate_sex, prate_violence, prate_genre, prate_MPAA_rating = get_parent_ratings_tweens()
        parent_ratings = youngsters, prate_consumerism, prate_drinking_drugs_smoking, prate_language, prate_positive_messages, prate_sex, prate_violence, prate_genre, prate_MPAA_rating
    movie_all_recs = find_all_similar_movies()
    movie_names = movie_all_recs.index
    if youngsters == 1:
        movie_recs = filter_movies_for_youngsters(parent_ratings, movie_names, df)
        return movie_recs
    else:
        movie_recs = filter_movies_for_tweens(parent_ratings, movie_names, df)
        return movie_recs

def get_parent_ratings_youngsters():
    print("I have just 9 more questions for you. Respond with a ? if you'd like some examples.")
    wants_educational = get_wants_educational()
    prate_sexy_stuff = get_prate_sexy_stuff()
    prate_violence_scariness = get_prate_violence_scariness()
    prate_consumerism = get_prate_consumerism()
    prate_drinking_drugs_smoking = get_prate_drinking_drugs_smoking()
    prate_language = get_prate_language()
    prate_positive_messages = get_prate_positive_messages()
    prate_genre = get_prate_genre()
    prate_MPAA_rating = get_prate_MPAA_rating()
    print("Thank you!")

    return wants_educational, prate_sexy_stuff, prate_violence_scariness, prate_consumerism, prate_drinking_drugs_smoking, prate_language, prate_positive_messages, prate_genre, prate_MPAA_rating

def get_parent_ratings_tweens():
    print("I have just 8 more questions for you. Respond with a ? if you'd like some examples.")
    prate_consumerism = get_prate_consumerism()
    prate_drinking_drugs_smoking = get_prate_drinking_drugs_smoking()
    prate_language = get_prate_language()
    prate_positive_messages = get_prate_positive_messages()
    prate_sex = get_prate_sex()
    prate_violence = get_prate_violence()
    prate_genre = get_prate_genre()
    prate_MPAA_rating = get_prate_MPAA_rating()
    print("Thank you!")

    return prate_consumerism, prate_drinking_drugs_smoking, prate_language, prate_positive_messages, prate_sex, prate_violence, prate_genre, prate_MPAA_rating

def get_num_children_and_ages():
    num_children = input("How many children do you have?")
    child = 0
    children_ages = []
    while child < int(num_children):
        print("How old is your child", child + 1, "?")
        child_age = input()
        children_ages.append(float(child_age))
        child += 1
    print("Thank you!")
    return int(num_children), children_ages

def age_checker(children_ages):
    youngsters = 0
    for age in children_ages:
        if age <= 8:
            youngsters = 1
    return youngsters

def get_wants_educational():
    wants_educational = []
    print("Do you want to see an educational movie?")
    while True:
        wants_educational = input("Please enter y, n, or ?")
        if (wants_educational == '?' or
            wants_educational == 'y' or
            wants_educational == 'n'):
            if wants_educational == '?':
                print("An example of an \'educational movie\' is", df[df['Educational Value']==3]['title'].iloc[random.randint(0,len(df[df['Educational Value']==3])-1)])
                print("An example of a non-educational movie is", df[df['Educational Value']==0]['title'].iloc[random.randint(0,len(df[df['Educational Value']==0])-1)])
            else:
                return wants_educational

def get_prate_sexy_stuff():
    prate_sexy_stuff = []
    print("What amount of \"sexy stuff\" is okay for your kids, on a scale of 0 to 3?)")
    while True:
        prate_sexy_stuff = input("Please enter 0, 1, 2, 3, or ?")
        if (prate_sexy_stuff == '?' or
            prate_sexy_stuff == '0' or
            prate_sexy_stuff == '1' or
            prate_sexy_stuff == '2' or
            prate_sexy_stuff == '3'):
            if prate_sexy_stuff == '?':
                print("An example of a 0 is", df[df['Sexy Stuff']==0]['title'].iloc[random.randint(0, len(df[df['Sexy Stuff']==0])-1)])
                print("An example of a 3 is", df[df['Sexy Stuff']==3]['title'].iloc[random.randint(0, len(df[df['Sexy Stuff']==3])-1)])
                print("(There are no movies rated higher than a 3 for Sexy Stuff...)")
            else:
                return prate_sexy_stuff

def get_prate_violence_scariness():
    prate_violence_scariness = []
    print("What level of violence and cartoon scariness is okay for your kids? (0 to 4)")
    while True:
        prate_violence_scariness = input("Please enter 0, 1, 2, 3, 4, or ?")
        if (prate_violence_scariness == '?' or
            prate_violence_scariness == '0' or
            prate_violence_scariness == '1' or
            prate_violence_scariness == '2' or
            prate_violence_scariness == '3' or
            prate_violence_scariness == '4'):
            if prate_violence_scariness == '?':
                print("An example of a 0 is", df[df['Violence & Scariness']==0]['title'].iloc[random.randint(0, len(df[df['Violence & Scariness']==0])-1)])
                print("An example of a 2 is", df[df['Violence & Scariness']==2]['title'].iloc[random.randint(0, len(df[df['Violence & Scariness']==2])-1)])
                print("An example of a 4 is", df[df['Violence & Scariness']==4]['title'].iloc[random.randint(0, len(df[df['Violence & Scariness']==4])-1)])
                print("(There are no movies with a 5 rating for Violence & Scariness...)")
            else:
                return prate_violence_scariness

def get_prate_consumerism():
    prate_consumerism = []
    print("What level of exposure to consumerism is okay for your kids? (0 to 5)")
    while True:
        prate_consumerism = input("Please enter 0, 1, 2, 3, 4, 5, or ?")
        if (prate_consumerism == '?' or
            prate_consumerism == '0' or
            prate_consumerism == '1' or
            prate_consumerism == '2' or
            prate_consumerism == '3' or
            prate_consumerism == '4' or
            prate_consumerism == '5'):
            if prate_consumerism == '?':
                print("An example of a 0 is", df[df['Consumerism']==0]['title'].iloc[random.randint(0, len(df[df['Consumerism']==0])-1)])
                print("An example of a 3 is", df[df['Consumerism']==3]['title'].iloc[random.randint(0, len(df[df['Consumerism']==3])-1)])
                print("An example of a 5 is", df[df['Consumerism']==5]['title'].iloc[random.randint(0, len(df[df['Consumerism']==5])-1)])
            else:
                return prate_consumerism

def get_prate_drinking_drugs_smoking():
    prate_drinking_drugs_smoking = []
    print("What level of drinking, drugs, & smoking is okay for your kids? (0 to 5)")
    while True:
        prate_drinking_drugs_smoking = input("Please enter 0, 1, 2, 3, 4, 5, or ?")
        if (prate_drinking_drugs_smoking == '?' or
            prate_drinking_drugs_smoking == '0' or
            prate_drinking_drugs_smoking == '1' or
            prate_drinking_drugs_smoking == '2' or
            prate_drinking_drugs_smoking == '3' or
            prate_drinking_drugs_smoking == '4' or
            prate_drinking_drugs_smoking == '5'):
            if prate_drinking_drugs_smoking == '?':
                print("An example of a 0 is", df[df['Drinking, Drugs & Smoking']==0]['title'].iloc[random.randint(0, len(df[df['Drinking, Drugs & Smoking']==0])-1)])
                print("An example of a 3 is", df[df['Drinking, Drugs & Smoking']==3]['title'].iloc[random.randint(0, len(df[df['Drinking, Drugs & Smoking']==3])-1)])
                print("An example of a 5 is", df[df['Drinking, Drugs & Smoking']==5]['title'].iloc[random.randint(0, len(df[df['Drinking, Drugs & Smoking']==5])-1)])
            else:
                return prate_drinking_drugs_smoking

def get_prate_language():
    prate_language = []
    print("What level of exposure to bad language is okay for your kids? (0 to 5)")
    while True:
        prate_language = input("Please enter 0, 1, 2, 3, 4, 5, or ?")
        if (prate_language == '?' or
            prate_language == '0' or
            prate_language == '1' or
            prate_language == '2' or
            prate_language == '3' or
            prate_language == '4' or
            prate_language == '5'):
            if prate_language == '?':
                print("An example of a 0 is", df[df['Language']==0]['title'].iloc[random.randint(0, len(df[df['Language']==0])-1)])
                print("An example of a 3 is", df[df['Language']==3]['title'].iloc[random.randint(0, len(df[df['Language']==3])-1)])
                print("An example of a 5 is", df[df['Language']==5]['title'].iloc[random.randint(0, len(df[df['Language']==5])-1)])
            else:
                return prate_language

def get_prate_positive_messages():
    prate_positive_messages = []
    print("How important are positive messages in movies to you and kids? (0 to 5)")
    while True:
        prate_positive_messages = input("Please enter 0, 1, 2, 3, 4, 5, or ?")
        if (prate_positive_messages == '?' or
            prate_positive_messages == '0' or
            prate_positive_messages == '1' or
            prate_positive_messages == '2' or
            prate_positive_messages == '3' or
            prate_positive_messages == '4' or
            prate_positive_messages == '5'):
            if prate_positive_messages == '?':
                print("An example of a 0 is", df[df['Positive Messages']==0]['title'].iloc[random.randint(0, len(df[df['Positive Messages']==0])-1)])
                print("An example of a 3 is", df[df['Positive Messages']==3]['title'].iloc[random.randint(0, len(df[df['Positive Messages']==3])-1)])
                print("An example of a 5 is", df[df['Positive Messages']==5]['title'].iloc[random.randint(0, len(df[df['Positive Messages']==5])-1)])
            else:
                return prate_positive_messages

def get_prate_sex():
    prate_sex = []
    print("What degree of exposure to sex in movies is okay for your kids? (0 to 5)")
    while True:
        prate_sex = input("Please enter 0, 1, 2, 3, 4, 5, or ?")
        if (prate_sex == '?' or
            prate_sex == '0' or
            prate_sex == '1' or
            prate_sex == '2' or
            prate_sex == '3' or
            prate_sex == '4' or
            prate_sex == '5'):
            if prate_sex == '?':
                print("An example of a 0 is", df[df['Sex']==0]['title'].iloc[random.randint(0, len(df[df['Sex']==0])-1)])
                print("An example of a 3 is", df[df['Sex']==3]['title'].iloc[random.randint(0, len(df[df['Sex']==3])-1)])
                print("An example of a 5 is", df[df['Sex']==5]['title'].iloc[random.randint(0, len(df[df['Sex']==5])-1)])
            else:
                return prate_sex

def get_prate_violence():
    prate_violence = []
    print("What level of movie violence is okay for your kids (0 to 5)")
    while True:
        prate_violence = input("Please enter 0, 1, 2, 3, 4, 5, or ?")
        if (prate_violence == '?' or
            prate_violence == '0' or
            prate_violence == '1' or
            prate_violence == '2' or
            prate_violence == '3' or
            prate_violence == '4' or
            prate_violence == '5'):
            if prate_violence == '?':
                print("An example of a 0 is", df[df['Violence']==0]['title'].iloc[random.randint(0, len(df[df['Violence']==0])-1)])
                print("An example of a 3 is", df[df['Violence']==3]['title'].iloc[random.randint(0, len(df[df['Violence']==3])-1)])
                print("An example of a 5 is", df[df['Violence']==5]['title'].iloc[random.randint(0, len(df[df['Violence']==5])-1)])
            else:
                return prate_violence

def get_prate_genre():
    prate_genre = []
    print("What genre of movie would you like to see?")
    while True:
        print("Please enter Drama, Family and Kids, Comedy, Action/Adventure, Documentary, Thriller,")
        prate_genre = input("Horror, Science Fiction, Fantasy, Romance, Musical, Classic, Western, or ?")
        if (prate_genre == '?' or
            prate_genre == 'Drama' or
            prate_genre == 'Family and Kids' or
            prate_genre == 'Comedy' or
            prate_genre == 'Action/Adventure' or
            prate_genre == 'Documentary' or
            prate_genre == 'Thriller' or
            prate_genre == 'Horror' or
            prate_genre == 'Science Fiction' or
            prate_genre == 'Fantasy' or
            prate_genre == 'Romance' or
            prate_genre == 'Musical' or
            prate_genre == 'Classic' or
            prate_genre == 'Western'):
            if prate_genre == '?':
                print("An example of a Drama is", df[df['genre']=='Drama']['title'].iloc[random.randint(0, len(df[df['genre']=='Drama'])-1)])
                print("An example of a Family and Kids movie is", df[df['genre']=='Family and Kids']['title'].iloc[random.randint(0, len(df[df['genre']=='Family and Kids'])-1)])
                print("An example of a Comedy is", df[df['genre']=='Comedy']['title'].iloc[random.randint(0, len(df[df['genre']=='Comedy'])-1)])
                print("An example of an Action/Adventure movie is", df[df['genre']=='Action/Adventure']['title'].iloc[random.randint(0, len(df[df['genre']=='Action/Adventure'])-1)])
                print("An example of a Documentary is", df[df['genre']=='Documentary']['title'].iloc[random.randint(0, len(df[df['genre']=='Documentary'])-1)])
                print("An example of a Thriller is", df[df['genre']=='Thriller']['title'].iloc[random.randint(0, len(df[df['genre']=='Thriller'])-1)])
                print("An example of a Horror movie is", df[df['genre']=='Horror']['title'].iloc[random.randint(0, len(df[df['genre']=='Horror'])-1)])
                print("An example of a Science Fiction movie is", df[df['genre']=='Science Fiction']['title'].iloc[random.randint(0, len(df[df['genre']=='Science Fiction'])-1)])
                print("An example of a Fantasy movie is", df[df['genre']=='Fantasy']['title'].iloc[random.randint(0, len(df[df['genre']=='Fantasy'])-1)])
                print("An example of a Romance is", df[df['genre']=='Romance']['title'].iloc[random.randint(0, len(df[df['genre']=='Romance'])-1)])
                print("An example of a Musical is", df[df['genre']=='Musical']['title'].iloc[random.randint(0, len(df[df['genre']=='Musical'])-1)])
                print("An example of a Classic film is", df[df['genre']=='Classic']['title'].iloc[random.randint(0, len(df[df['genre']=='Classic'])-1)])
                print("An example of a Western is", df[df['genre']=='Western']['title'].iloc[random.randint(0, len(df[df['genre']=='Western'])-1)])
            else:
                return prate_genre

def get_prate_MPAA_rating():
    prate_MPAA_rating = []
    print("Finally, what MPAA rating is the most extreme MPAA Rating for your kids (G, PG, PG-13, R, NR (not rated), or NC-17?)")
    while True:
        prate_MPAA_rating = input("Please enter G, PG, PG-13, R, NR (not rated), NC-17, or ?")
        if (prate_MPAA_rating == '?' or
            prate_MPAA_rating == 'G' or
            prate_MPAA_rating == 'PG' or
            prate_MPAA_rating == 'PG-13' or
            prate_MPAA_rating == 'R' or
            prate_MPAA_rating == 'NR' or
            prate_MPAA_rating == 'NC-17'):
            if prate_MPAA_rating == '?':
                print("An example of a G rated movie is", df[df['MPAA_rating']=='G']['title'].iloc[random.randint(0, len(df[df['MPAA_rating']=='G'])-1)])
                print("An example of a PG rated movie is", df[df['MPAA_rating']=='PG']['title'].iloc[random.randint(0, len(df[df['MPAA_rating']=='PG'])-1)])
                print("An example of a PG-13 rated movie is", df[df['MPAA_rating']=='PG-13']['title'].iloc[random.randint(0, len(df[df['MPAA_rating']=='PG-13'])-1)])
                print("An example of an R rated movie is", df[df['MPAA_rating']=='R']['title'].iloc[random.randint(0, len(df[df['MPAA_rating']=='R'])-1)])
                print("An example of an NR rated movie is", df[df['MPAA_rating']=='NR']['title'].iloc[random.randint(0, len(df[df['MPAA_rating']=='NR'])-1)])
                print("An example of an NC-17 rated movie is", df[df['MPAA_rating']=='NC-17']['title'].iloc[random.randint(0, len(df[df['MPAA_rating']=='NC-17'])-1)])
            if prate_MPAA_rating == 'G':
                prate_MPAA_rating = 0
            if prate_MPAA_rating == 'PG':
                prate_MPAA_rating = 1
            if prate_MPAA_rating == 'PG-13':
                prate_MPAA_rating = 2
            if prate_MPAA_rating == 'R':
                prate_MPAA_rating = 3
            if prate_MPAA_rating == 'NR':
                prate_MPAA_rating = 4
            if prate_MPAA_rating == 'NC-17':
                prate_MPAA_rating = 5
        else:
            return prate_MPAA_rating

# %%
movie_recs.index
# Out:
# pandas.core.indexes.base.Index

# %%
get_parent_ratings_first()
# Out:
# Welcome to MovieRec4Parents! Let me ask you a few questions before we begin.
# How many children do you have?1
# How old is your child 1 ?
# 14
# Thank you!
# I have just 8 more questions for you. Respond with a ? if you'd like some examples.
# What level of exposure to consumerism is okay for your kids? (0 to 5)
# Please enter 0, 1, 2, 3, 4, 5, or ?5
# What level of drinking, drugs, & smoking is okay for your kids? (0 to 5)
# Please enter 0, 1, 2, 3, 4, 5, or ?5
# What level of exposure to bad language is okay for your kids? (0 to 5)
# Please enter 0, 1, 2, 3, 4, 5, or ?5
# How important are positive messages in movies to you and kids? (0 to 5)
# Please enter 0, 1, 2, 3, 4, 5, or ?0
# What degree of exposure to sex in movies is okay for your kids? (0 to 5)
# Please enter 0, 1, 2, 3, 4, 5, or ?5
# What level of movie violence is okay for your kids (0 to 5)
# Please enter 0, 1, 2, 3, 4, 5, or ?5
# What genre of movie would you like to see?
# Please enter Drama, Family and Kids, Comedy, Action/Adventure, Documentary, Thriller,
# Horror, Science Fiction, Fantasy, Romance, Musical, Classic, Western, or ?Horror
# Finally, what MPAA rating is the most extreme MPAA Rating for your kids (G, PG, PG-13, R, NR (not rated), or NC-17?)
# Please enter G, PG, PG-13, R, NR (not rated), NC-17, or ?NC-17
# Please enter G, PG, PG-13, R, NR (not rated), NC-17, or ?NC-17
# Please enter G, PG, PG-13, R, NR (not rated), NC-17, or ?NR
# Thank you!
# Give me a movie title and I'll give you five titles you might also like:Toy Story (1995)
# Thanks! Here are my recommendations, along with review text similarity scores:
# Here are your recommended movies:
# ['The Last House on the Left (1972)',
#  'American Psycho',
#  'Stuck',
#  'Rise: Blood Hunter',
#  'V/H/S/2']

# %%
df.title[df.title=='Toy Story (1995)'].index.tolist()[0]
# Out:
# 4279

# %%
df.head()
# Out:
#    Unnamed: 0  Consumerism  Drinking, Drugs & Smoking  Educational Value  \
# 0           0          0.0                        3.0                NaN
# 1           1          0.0                        3.0                NaN
# 2           2          0.0                        2.0                NaN
# 3           3          0.0                        1.0                NaN
# 4           4          0.0                        4.0                NaN
#
#    Language MPAA_rating  Positive Messages  Sex  Sexy Stuff  Violence  \
# 0       4.0           R                1.0  0.0         NaN       4.0
# 1       4.0           R                0.0  3.0         NaN       4.0
# 2       0.0           R                1.0  0.0         NaN       3.0
# 3       3.0           R                3.0  2.0         NaN       3.0
# 4       4.0           R                1.0  4.0         NaN       2.0
#
#              ...                genre  movie_id  \
# 0            ...             Thriller         0
# 1            ...              Western         1
# 2            ...             Thriller         2
# 3            ...             Thriller         3
# 4            ...               Comedy         4
#
#                                 one_line_description  overall_rating  \
# 0  Solid drug war sequel has intense violence, la...               3
# 1  Unusual, uneven Western has violence, language...               3
# 2  Rapid-fire disturbing images in paranoid thril...               2
# 3  Well-made spy thriller has some war violence, ...               4
# 4   Indie road-trip dramedy has pot dealing/smoking.               2
#
#                          slug                        title MPAA_ordinal  \
# 0  sicario-day-of-the-soldado  Sicario: Day of the Soldado            3
# 1                      damsel                       Damsel            3
# 2                   distorted                    Distorted            3
# 3       the-catcher-was-a-spy        The Catcher Was a Spy            3
# 4                  boundaries                   Boundaries            3
#
#   is_educational  has_Sexy_Stuff  has_Violence_&_Scariness
# 0              0               0                         0
# 1              0               0                         0
# 2              0               0                         0
# 3              0               0                         0
# 4              0               0                         0
#
# [5 rows x 22 columns]

# %%
df['title'][0]
# Out:
# 'Sicario: Day of the Soldado'

# %%
recommendations = find_similar_movies()
# Out:
# Give me a movie title and I'll give you five titles you might also like:Avenger
# Sorry, that movie title isn't in my list. Did you mean [('Avengers: Infinity War', 90), ('Avengers: Age of Ultron', 90), ('The Avengers', 90)] ?
# (I need the exact title, please...)Avengers: Infinity War
# Thanks! Here are my recommendations, along with review text similarity scores:

# %%
recommendations.index
# Out:
# Index(['Avengers: Age of Ultron', 'The Avengers', 'Captain America: Civil War',
#        'Next Avengers: Heroes of Tomorrow',
#        'Ultimate Avengers 2: Rise of the Panther'],
#       dtype='object', name='title')

# %%
df.index
# Out:
# Index(['Sicario: Day of the Soldado', 'Damsel', 'Distorted',
#        'The Catcher Was a Spy', 'Boundaries', 'Izzy Gets the F*ck Across Town',
#        'Jurassic World: Fallen Kingdom', 'Brothers of the Wind', 'Unsane',
#        'Flower',
#        ...
#        'Live and Let Die', 'Tintin: The Lake of Sharks',
#        'Tales of Beatrix Potter', 'Tintin: The Prisoners of the Sun',
#        'Gentle Giant', 'Tintin: The Calculus Affair',
#        'Visit to a Small Planet', 'Zoo Baby', 'Driftwood', 'Sherlock Jr.'],
#       dtype='object', name='title', length=8625)

# %%
df[df['MPAA_rating']=='G']
# Out:
#                                                     Consumerism  \
# title
# Alex &amp; Me                                               1.0
# Daphne &amp; Velma                                          2.0
# Pup Star: World Tour                                        0.0
# Pandas                                                      0.0
# Ladies First                                                0.0
# Benji                                                       1.0
# Earth: One Amazing Day                                      0.0
# 48 Christmas Wishes                                         2.0
# All I Want for Christmas Is You                             2.0
# Cars 3                                                      3.0
# Spookley the Square Pumpkin                                 0.0
# Ghost of the Mountains                                      0.0
# Born in China                                               0.0
# The Horse Dancer                                            3.0
# Americano                                                   0.0
# Bambi                                                       0.0
# Ozzy: The Fast and Furriest                                 1.0
# The Swan Princess: Royally Undercover                       2.0
# Robo-Dog: Airborne                                          0.0
# The Eagle Huntress                                          1.0
# Pinocchio                                                   2.0
# Tini: The New Life of Violetta                              0.0
# Disneynature: Expedition China                              0.0
# Dolly Parton's Christmas of Many Colors: Circle...          0.0
# Growing Up Wild                                             0.0
# Arlo the Burping Pig                                        0.0
# Motu Patlu: King of Kings                                   0.0
# Wild Kratts: A Creature Christmas                           1.0
# A Boy Named Charlie Brown                                   3.0
# Snoopy, Come Home                                           3.0
# ...                                                         ...
# The Jungle Book: Mowgli's Story                             0.0
# The Real Macaw                                              1.0
# A Little Princess                                           0.0
# Oliver!                                                     0.0
# The Return of Jafar                                         3.0
# Kids for Character                                          0.0
# Animal Crackers                                             0.0
# FernGully 2: The Magical Rescue                             0.0
# The Secret of NIMH 2: Timmy to the Rescue                   0.0
# Babe                                                        0.0
# George Balanchine's The Nutcracker                          0.0
# Darby O'Gill and the Little People                          0.0
# Herbie Rides Again                                          0.0
# The Pebble and the Penguin                                  0.0
# The Adventures of Milo and Otis                             0.0
# The Magic of the Golden Bear: Goldy III                     0.0
# The Secret of NIMH                                          0.0
# Homeward Bound: The Incredible Journey                      0.0
# Jetsons: The Movie                                          0.0
# The Phantom Tollbooth                                       0.0
# 2001: A Space Odyssey                                       2.0
# Babar: The Movie                                            1.0
# Hansel and Gretel                                           0.0
# The New Adventures of Pippi Longstocking                    1.0
# The Man from Button Willow                                  0.0
# The Frog Prince                                             0.0
# The Life and Adventures of Santa Claus (1985)               0.0
# The Strongest Man in the World                              0.0
# Tales of Beatrix Potter                                     0.0
# Tintin: The Calculus Affair                                 0.0
#
#                                                     Drinking, Drugs & Smoking  \
# title
# Alex &amp; Me                                                             0.0
# Daphne &amp; Velma                                                        0.0
# Pup Star: World Tour                                                      0.0
# Pandas                                                                    0.0
# Ladies First                                                              0.0
# Benji                                                                     0.0
# Earth: One Amazing Day                                                    0.0
# 48 Christmas Wishes                                                       0.0
# All I Want for Christmas Is You                                           0.0
# Cars 3                                                                    1.0
# Spookley the Square Pumpkin                                               0.0
# Ghost of the Mountains                                                    0.0
# Born in China                                                             0.0
# The Horse Dancer                                                          0.0
# Americano                                                                 0.0
# Bambi                                                                     0.0
# Ozzy: The Fast and Furriest                                               0.0
# The Swan Princess: Royally Undercover                                     0.0
# Robo-Dog: Airborne                                                        0.0
# The Eagle Huntress                                                        0.0
# Pinocchio                                                                 3.0
# Tini: The New Life of Violetta                                            0.0
# Disneynature: Expedition China                                            0.0
# Dolly Parton's Christmas of Many Colors: Circle...                        0.0
# Growing Up Wild                                                           0.0
# Arlo the Burping Pig                                                      0.0
# Motu Patlu: King of Kings                                                 0.0
# Wild Kratts: A Creature Christmas                                         0.0
# A Boy Named Charlie Brown                                                 0.0
# Snoopy, Come Home                                                         0.0
# ...                                                                       ...
# The Jungle Book: Mowgli's Story                                           0.0
# The Real Macaw                                                            2.0
# A Little Princess                                                         1.0
# Oliver!                                                                   3.0
# The Return of Jafar                                                       0.0
# Kids for Character                                                        0.0
# Animal Crackers                                                           3.0
# FernGully 2: The Magical Rescue                                           0.0
# The Secret of NIMH 2: Timmy to the Rescue                                 0.0
# Babe                                                                      0.0
# George Balanchine's The Nutcracker                                        0.0
# Darby O'Gill and the Little People                                        3.0
# Herbie Rides Again                                                        0.0
# The Pebble and the Penguin                                                0.0
# The Adventures of Milo and Otis                                           0.0
# The Magic of the Golden Bear: Goldy III                                   1.0
# The Secret of NIMH                                                        1.0
# Homeward Bound: The Incredible Journey                                    0.0
# Jetsons: The Movie                                                        0.0
# The Phantom Tollbooth                                                     0.0
# 2001: A Space Odyssey                                                     0.0
# Babar: The Movie                                                          0.0
# Hansel and Gretel                                                         0.0
# The New Adventures of Pippi Longstocking                                  1.0
# The Man from Button Willow                                                1.0
# The Frog Prince                                                           0.0
# The Life and Adventures of Santa Claus (1985)                             0.0
# The Strongest Man in the World                                            0.0
# Tales of Beatrix Potter                                                   1.0
# Tintin: The Calculus Affair                                               2.0
#
#                                                     Educational Value  \
# title
# Alex &amp; Me                                                     0.0
# Daphne &amp; Velma                                                0.0
# Pup Star: World Tour                                              1.0
# Pandas                                                            4.0
# Ladies First                                                      NaN
# Benji                                                             0.0
# Earth: One Amazing Day                                            3.0
# 48 Christmas Wishes                                               0.0
# All I Want for Christmas Is You                                   0.0
# Cars 3                                                            2.0
# Spookley the Square Pumpkin                                       0.0
# Ghost of the Mountains                                            4.0
# Born in China                                                     4.0
# The Horse Dancer                                                  NaN
# Americano                                                         1.0
# Bambi                                                             2.0
# Ozzy: The Fast and Furriest                                       NaN
# The Swan Princess: Royally Undercover                             0.0
# Robo-Dog: Airborne                                                0.0
# The Eagle Huntress                                                4.0
# Pinocchio                                                         NaN
# Tini: The New Life of Violetta                                    NaN
# Disneynature: Expedition China                                    2.0
# Dolly Parton's Christmas of Many Colors: Circle...                0.0
# Growing Up Wild                                                   2.0
# Arlo the Burping Pig                                              0.0
# Motu Patlu: King of Kings                                         0.0
# Wild Kratts: A Creature Christmas                                 3.0
# A Boy Named Charlie Brown                                         2.0
# Snoopy, Come Home                                                 0.0
# ...                                                               ...
# The Jungle Book: Mowgli's Story                                   1.0
# The Real Macaw                                                    0.0
# A Little Princess                                                 NaN
# Oliver!                                                           2.0
# The Return of Jafar                                               NaN
# Kids for Character                                                NaN
# Animal Crackers                                                   NaN
# FernGully 2: The Magical Rescue                                   1.0
# The Secret of NIMH 2: Timmy to the Rescue                         NaN
# Babe                                                              2.0
# George Balanchine's The Nutcracker                                NaN
# Darby O'Gill and the Little People                                NaN
# Herbie Rides Again                                                NaN
# The Pebble and the Penguin                                        NaN
# The Adventures of Milo and Otis                                   1.0
# The Magic of the Golden Bear: Goldy III                           0.0
# The Secret of NIMH                                                0.0
# Homeward Bound: The Incredible Journey                            1.0
# Jetsons: The Movie                                                NaN
# The Phantom Tollbooth                                             NaN
# 2001: A Space Odyssey                                             NaN
# Babar: The Movie                                                  2.0
# Hansel and Gretel                                                 0.0
# The New Adventures of Pippi Longstocking                          1.0
# The Man from Button Willow                                        0.0
# The Frog Prince                                                   0.0
# The Life and Adventures of Santa Claus (1985)                     0.0
# The Strongest Man in the World                                    NaN
# Tales of Beatrix Potter                                           3.0
# Tintin: The Calculus Affair                                       NaN
#
#                                                     Language MPAA_rating  \
# title
# Alex &amp; Me                                            0.0           G
# Daphne &amp; Velma                                       0.0           G
# Pup Star: World Tour                                     0.0           G
# Pandas                                                   0.0           G
# Ladies First                                             0.0           G
# Benji                                                    0.0           G
# Earth: One Amazing Day                                   0.0           G
# 48 Christmas Wishes                                      0.0           G
# All I Want for Christmas Is You                          0.0           G
# Cars 3                                                   1.0           G
# Spookley the Square Pumpkin                              0.0           G
# Ghost of the Mountains                                   0.0           G
# Born in China                                            0.0           G
# The Horse Dancer                                         0.0           G
# Americano                                                1.0           G
# Bambi                                                    0.0           G
# Ozzy: The Fast and Furriest                              0.0           G
# The Swan Princess: Royally Undercover                    0.0           G
# Robo-Dog: Airborne                                       0.0           G
# The Eagle Huntress                                       0.0           G
# Pinocchio                                                0.0           G
# Tini: The New Life of Violetta                           0.0           G
# Disneynature: Expedition China                           0.0           G
# Dolly Parton's Christmas of Many Colors: Circle...       0.0           G
# Growing Up Wild                                          0.0           G
# Arlo the Burping Pig                                     0.0           G
# Motu Patlu: King of Kings                                0.0           G
# Wild Kratts: A Creature Christmas                        0.0           G
# A Boy Named Charlie Brown                                1.0           G
# Snoopy, Come Home                                        1.0           G
# ...                                                      ...         ...
# The Jungle Book: Mowgli's Story                          1.0           G
# The Real Macaw                                           0.0           G
# A Little Princess                                        0.0           G
# Oliver!                                                  0.0           G
# The Return of Jafar                                      0.0           G
# Kids for Character                                       0.0           G
# Animal Crackers                                          0.0           G
# FernGully 2: The Magical Rescue                          0.0           G
# The Secret of NIMH 2: Timmy to the Rescue                0.0           G
# Babe                                                     1.0           G
# George Balanchine's The Nutcracker                       0.0           G
# Darby O'Gill and the Little People                       0.0           G
# Herbie Rides Again                                       0.0           G
# The Pebble and the Penguin                               0.0           G
# The Adventures of Milo and Otis                          1.0           G
# The Magic of the Golden Bear: Goldy III                  0.0           G
# The Secret of NIMH                                       1.0           G
# Homeward Bound: The Incredible Journey                   0.0           G
# Jetsons: The Movie                                       0.0           G
# The Phantom Tollbooth                                    0.0           G
# 2001: A Space Odyssey                                    1.0           G
# Babar: The Movie                                         0.0           G
# Hansel and Gretel                                        1.0           G
# The New Adventures of Pippi Longstocking                 2.0           G
# The Man from Button Willow                               1.0           G
# The Frog Prince                                          0.0           G
# The Life and Adventures of Santa Claus (1985)            0.0           G
# The Strongest Man in the World                           0.0           G
# Tales of Beatrix Potter                                  0.0           G
# Tintin: The Calculus Affair                              1.0           G
#
#                                                     Positive Messages  Sex  \
# title
# Alex &amp; Me                                                     5.0  0.0
# Daphne &amp; Velma                                                1.0  0.0
# Pup Star: World Tour                                              2.0  0.0
# Pandas                                                            4.0  0.0
# Ladies First                                                      4.0  0.0
# Benji                                                             3.0  0.0
# Earth: One Amazing Day                                            4.0  0.0
# 48 Christmas Wishes                                               2.0  0.0
# All I Want for Christmas Is You                                   3.0  0.0
# Cars 3                                                            4.0  0.0
# Spookley the Square Pumpkin                                       4.0  0.0
# Ghost of the Mountains                                            4.0  0.0
# Born in China                                                     3.0  0.0
# The Horse Dancer                                                  4.0  0.0
# Americano                                                         3.0  0.0
# Bambi                                                             3.0  0.0
# Ozzy: The Fast and Furriest                                       0.0  0.0
# The Swan Princess: Royally Undercover                             3.0  0.0
# Robo-Dog: Airborne                                                1.0  0.0
# The Eagle Huntress                                                5.0  0.0
# Pinocchio                                                         4.0  0.0
# Tini: The New Life of Violetta                                    0.0  0.0
# Disneynature: Expedition China                                    3.0  0.0
# Dolly Parton's Christmas of Many Colors: Circle...                5.0  0.0
# Growing Up Wild                                                   3.0  0.0
# Arlo the Burping Pig                                              2.0  0.0
# Motu Patlu: King of Kings                                         2.0  0.0
# Wild Kratts: A Creature Christmas                                 3.0  0.0
# A Boy Named Charlie Brown                                         5.0  0.0
# Snoopy, Come Home                                                 3.0  0.0
# ...                                                               ...  ...
# The Jungle Book: Mowgli's Story                                   2.0  0.0
# The Real Macaw                                                    2.0  0.0
# A Little Princess                                                 3.0  0.0
# Oliver!                                                           2.0  0.0
# The Return of Jafar                                               3.0  0.0
# Kids for Character                                                0.0  0.0
# Animal Crackers                                                   0.0  0.0
# FernGully 2: The Magical Rescue                                   3.0  0.0
# The Secret of NIMH 2: Timmy to the Rescue                         3.0  0.0
# Babe                                                              4.0  0.0
# George Balanchine's The Nutcracker                                3.0  0.0
# Darby O'Gill and the Little People                                3.0  0.0
# Herbie Rides Again                                                3.0  0.0
# The Pebble and the Penguin                                        3.0  0.0
# The Adventures of Milo and Otis                                   3.0  0.0
# The Magic of the Golden Bear: Goldy III                           2.0  0.0
# The Secret of NIMH                                                2.0  0.0
# Homeward Bound: The Incredible Journey                            4.0  0.0
# Jetsons: The Movie                                                0.0  0.0
# The Phantom Tollbooth                                             0.0  0.0
# 2001: A Space Odyssey                                             3.0  0.0
# Babar: The Movie                                                  4.0  0.0
# Hansel and Gretel                                                 2.0  0.0
# The New Adventures of Pippi Longstocking                          3.0  0.0
# The Man from Button Willow                                        1.0  0.0
# The Frog Prince                                                   2.0  0.0
# The Life and Adventures of Santa Claus (1985)                     2.0  0.0
# The Strongest Man in the World                                    0.0  0.0
# Tales of Beatrix Potter                                           3.0  0.0
# Tintin: The Calculus Affair                                       2.0  0.0
#
#                                                     Sexy Stuff  Violence  \
# title
# Alex &amp; Me                                              0.0       0.0
# Daphne &amp; Velma                                         0.0       0.0
# Pup Star: World Tour                                       0.0       0.0
# Pandas                                                     0.0       0.0
# Ladies First                                               NaN       2.0
# Benji                                                      0.0       0.0
# Earth: One Amazing Day                                     0.0       0.0
# 48 Christmas Wishes                                        NaN       0.0
# All I Want for Christmas Is You                            0.0       0.0
# Cars 3                                                     0.0       0.0
# Spookley the Square Pumpkin                                0.0       0.0
# Ghost of the Mountains                                     0.0       0.0
# Born in China                                              0.0       0.0
# The Horse Dancer                                           NaN       0.0
# Americano                                                  0.0       0.0
# Bambi                                                      1.0       0.0
# Ozzy: The Fast and Furriest                                NaN       3.0
# The Swan Princess: Royally Undercover                      0.0       0.0
# Robo-Dog: Airborne                                         0.0       0.0
# The Eagle Huntress                                         0.0       0.0
# Pinocchio                                                  1.0       0.0
# Tini: The New Life of Violetta                             1.0       0.0
# Disneynature: Expedition China                             1.0       0.0
# Dolly Parton's Christmas of Many Colors: Circle...         0.0       0.0
# Growing Up Wild                                            1.0       0.0
# Arlo the Burping Pig                                       0.0       0.0
# Motu Patlu: King of Kings                                  0.0       0.0
# Wild Kratts: A Creature Christmas                          0.0       0.0
# A Boy Named Charlie Brown                                  0.0       0.0
# Snoopy, Come Home                                          0.0       0.0
# ...                                                        ...       ...
# The Jungle Book: Mowgli's Story                            0.0       0.0
# The Real Macaw                                             0.0       0.0
# A Little Princess                                          0.0       0.0
# Oliver!                                                    0.0       0.0
# The Return of Jafar                                        0.0       0.0
# Kids for Character                                         0.0       0.0
# Animal Crackers                                            0.0       0.0
# FernGully 2: The Magical Rescue                            0.0       0.0
# The Secret of NIMH 2: Timmy to the Rescue                  0.0       0.0
# Babe                                                       0.0       0.0
# George Balanchine's The Nutcracker                         0.0       0.0
# Darby O'Gill and the Little People                         3.0       0.0
# Herbie Rides Again                                         0.0       0.0
# The Pebble and the Penguin                                 0.0       0.0
# The Adventures of Milo and Otis                            1.0       0.0
# The Magic of the Golden Bear: Goldy III                    0.0       0.0
# The Secret of NIMH                                         0.0       0.0
# Homeward Bound: The Incredible Journey                     0.0       0.0
# Jetsons: The Movie                                         0.0       0.0
# The Phantom Tollbooth                                      0.0       0.0
# 2001: A Space Odyssey                                      NaN       3.0
# Babar: The Movie                                           0.0       0.0
# Hansel and Gretel                                          0.0       0.0
# The New Adventures of Pippi Longstocking                   0.0       0.0
# The Man from Button Willow                                 0.0       0.0
# The Frog Prince                                            0.0       0.0
# The Life and Adventures of Santa Claus (1985)              1.0       0.0
# The Strongest Man in the World                             0.0       0.0
# Tales of Beatrix Potter                                    0.0       0.0
# Tintin: The Calculus Affair                                NaN       3.0
#
#                                                     Violence & Scariness  age  \
# title
# Alex &amp; Me                                                        1.0    8
# Daphne &amp; Velma                                                   2.0    8
# Pup Star: World Tour                                                 2.0    6
# Pandas                                                               2.0    6
# Ladies First                                                         NaN   10
# Benji                                                                3.0    7
# Earth: One Amazing Day                                               2.0    6
# 48 Christmas Wishes                                                  1.0    8
# All I Want for Christmas Is You                                      0.0    4
# Cars 3                                                               3.0    6
# Spookley the Square Pumpkin                                          1.0    4
# Ghost of the Mountains                                               2.0    6
# Born in China                                                        3.0    6
# The Horse Dancer                                                     NaN    9
# Americano                                                            3.0    7
# Bambi                                                                3.0    5
# Ozzy: The Fast and Furriest                                          NaN    9
# The Swan Princess: Royally Undercover                                2.0    6
# Robo-Dog: Airborne                                                   1.0    7
# The Eagle Huntress                                                   2.0    8
# Pinocchio                                                            3.0    6
# Tini: The New Life of Violetta                                       1.0    8
# Disneynature: Expedition China                                       2.0    6
# Dolly Parton's Christmas of Many Colors: Circle...                   1.0    7
# Growing Up Wild                                                      3.0    6
# Arlo the Burping Pig                                                 1.0    5
# Motu Patlu: King of Kings                                            3.0    7
# Wild Kratts: A Creature Christmas                                    0.0    5
# A Boy Named Charlie Brown                                            1.0    4
# Snoopy, Come Home                                                    2.0    6
# ...                                                                  ...  ...
# The Jungle Book: Mowgli's Story                                      3.0    7
# The Real Macaw                                                       2.0    7
# A Little Princess                                                    3.0    7
# Oliver!                                                              3.0    8
# The Return of Jafar                                                  3.0    5
# Kids for Character                                                   0.0    4
# Animal Crackers                                                      3.0    7
# FernGully 2: The Magical Rescue                                      3.0    5
# The Secret of NIMH 2: Timmy to the Rescue                            3.0    8
# Babe                                                                 3.0    6
# George Balanchine's The Nutcracker                                   0.0    5
# Darby O'Gill and the Little People                                   3.0    8
# Herbie Rides Again                                                   0.0    6
# The Pebble and the Penguin                                           3.0    7
# The Adventures of Milo and Otis                                      2.0    5
# The Magic of the Golden Bear: Goldy III                              2.0    7
# The Secret of NIMH                                                   3.0    8
# Homeward Bound: The Incredible Journey                               1.0    6
# Jetsons: The Movie                                                   0.0    4
# The Phantom Tollbooth                                                0.0    8
# 2001: A Space Odyssey                                                NaN   12
# Babar: The Movie                                                     2.0    5
# Hansel and Gretel                                                    3.0    8
# The New Adventures of Pippi Longstocking                             2.0    7
# The Man from Button Willow                                           2.0    5
# The Frog Prince                                                      1.0    6
# The Life and Adventures of Santa Claus (1985)                        2.0    5
# The Strongest Man in the World                                       0.0    6
# Tales of Beatrix Potter                                              2.0    3
# Tintin: The Calculus Affair                                          NaN    9
#
#                                                                genre  \
# title
# Alex &amp; Me                                        Family and Kids
# Daphne &amp; Velma                                   Family and Kids
# Pup Star: World Tour                                 Family and Kids
# Pandas                                                   Documentary
# Ladies First                                             Documentary
# Benji                                                Family and Kids
# Earth: One Amazing Day                                   Documentary
# 48 Christmas Wishes                                  Family and Kids
# All I Want for Christmas Is You                      Family and Kids
# Cars 3                                               Family and Kids
# Spookley the Square Pumpkin                          Family and Kids
# Ghost of the Mountains                                   Documentary
# Born in China                                            Documentary
# The Horse Dancer                                               Drama
# Americano                                            Family and Kids
# Bambi                                                Family and Kids
# Ozzy: The Fast and Furriest                          Family and Kids
# The Swan Princess: Royally Undercover                Family and Kids
# Robo-Dog: Airborne                                   Family and Kids
# The Eagle Huntress                                       Documentary
# Pinocchio                                            Family and Kids
# Tini: The New Life of Violetta                               Romance
# Disneynature: Expedition China                           Documentary
# Dolly Parton's Christmas of Many Colors: Circle...             Drama
# Growing Up Wild                                          Documentary
# Arlo the Burping Pig                                 Family and Kids
# Motu Patlu: King of Kings                            Family and Kids
# Wild Kratts: A Creature Christmas                    Family and Kids
# A Boy Named Charlie Brown                            Family and Kids
# Snoopy, Come Home                                    Family and Kids
# ...                                                              ...
# The Jungle Book: Mowgli's Story                      Family and Kids
# The Real Macaw                                                Comedy
# A Little Princess                                    Family and Kids
# Oliver!                                                      Musical
# The Return of Jafar                                  Family and Kids
# Kids for Character                                   Family and Kids
# Animal Crackers                                               Comedy
# FernGully 2: The Magical Rescue                      Family and Kids
# The Secret of NIMH 2: Timmy to the Rescue            Family and Kids
# Babe                                                 Family and Kids
# George Balanchine's The Nutcracker                   Family and Kids
# Darby O'Gill and the Little People                   Family and Kids
# Herbie Rides Again                                   Family and Kids
# The Pebble and the Penguin                           Family and Kids
# The Adventures of Milo and Otis                      Family and Kids
# The Magic of the Golden Bear: Goldy III              Family and Kids
# The Secret of NIMH                                   Family and Kids
# Homeward Bound: The Incredible Journey               Family and Kids
# Jetsons: The Movie                                   Family and Kids
# The Phantom Tollbooth                                Family and Kids
# 2001: A Space Odyssey                                Science Fiction
# Babar: The Movie                                     Family and Kids
# Hansel and Gretel                                    Family and Kids
# The New Adventures of Pippi Longstocking             Family and Kids
# The Man from Button Willow                          Action/Adventure
# The Frog Prince                                      Family and Kids
# The Life and Adventures of Santa Claus (1985)        Family and Kids
# The Strongest Man in the World                       Family and Kids
# Tales of Beatrix Potter                              Family and Kids
# Tintin: The Calculus Affair                         Action/Adventure
#
#                                                     movie_id  \
# title
# Alex &amp; Me                                             24
# Daphne &amp; Velma                                        70
# Pup Star: World Tour                                     201
# Pandas                                                   286
# Ladies First                                             352
# Benji                                                    394
# Earth: One Amazing Day                                   427
# 48 Christmas Wishes                                      466
# All I Want for Christmas Is You                          526
# Cars 3                                                   542
# Spookley the Square Pumpkin                              613
# Ghost of the Mountains                                   640
# Born in China                                            679
# The Horse Dancer                                         752
# Americano                                                793
# Bambi                                                    837
# Ozzy: The Fast and Furriest                              883
# The Swan Princess: Royally Undercover                    936
# Robo-Dog: Airborne                                       962
# The Eagle Huntress                                      1018
# Pinocchio                                               1033
# Tini: The New Life of Violetta                          1054
# Disneynature: Expedition China                          1072
# Dolly Parton's Christmas of Many Colors: Circle...      1087
# Growing Up Wild                                         1109
# Arlo the Burping Pig                                    1151
# Motu Patlu: King of Kings                               1201
# Wild Kratts: A Creature Christmas                       1226
# A Boy Named Charlie Brown                               1271
# Snoopy, Come Home                                       1272
# ...                                                      ...
# The Jungle Book: Mowgli's Story                         8518
# The Real Macaw                                          8522
# A Little Princess                                       8523
# Oliver!                                                 8536
# The Return of Jafar                                     8544
# Kids for Character                                      8565
# Animal Crackers                                         8575
# FernGully 2: The Magical Rescue                         8590
# The Secret of NIMH 2: Timmy to the Rescue               8622
# Babe                                                    8633
# George Balanchine's The Nutcracker                      8634
# Darby O'Gill and the Little People                      8712
# Herbie Rides Again                                      8713
# The Pebble and the Penguin                              8726
# The Adventures of Milo and Otis                         8727
# The Magic of the Golden Bear: Goldy III                 8730
# The Secret of NIMH                                      8738
# Homeward Bound: The Incredible Journey                  8742
# Jetsons: The Movie                                      8744
# The Phantom Tollbooth                                   8749
# 2001: A Space Odyssey                                   8753
# Babar: The Movie                                        8763
# Hansel and Gretel                                       8764
# The New Adventures of Pippi Longstocking                8765
# The Man from Button Willow                              8766
# The Frog Prince                                         8767
# The Life and Adventures of Santa Claus (1985)           8768
# The Strongest Man in the World                          8769
# Tales of Beatrix Potter                                 8772
# Tintin: The Calculus Affair                             8775
#
#                                                                                  one_line_description  \
# title
# Alex &amp; Me                                       Kid-friendly soccer tale scores with positive ...
# Daphne &amp; Velma                                  Live-action tale about high school besties has...
# Pup Star: World Tour                                Slapstick action and humor in musical talking-...
# Pandas                                              Educational doc about scientists training pand...
# Ladies First                                        Inspiring but cautionary docu about woman arch...
# Benji                                                 Adorable stray dog in '70s classic; some peril.
# Earth: One Amazing Day                              Some animal peril in beautifully filmed nature...
# 48 Christmas Wishes                                 Bland holiday tale turns dark; some emotional ...
# All I Want for Christmas Is You                     Merry, mischievous holiday tale is fun for fam...
# Cars 3                                              Some intense scenes in story of empowerment, m...
# Spookley the Square Pumpkin                         Delightful musical tale of pumpkin who doesn't...
# Ghost of the Mountains                              Absorbing docu about snow leopards has mild pe...
# Born in China                                       Nature docu has gorgeous vistas, moments of pe...
# The Horse Dancer                                    Tired horse tale with silly plot, poor product...
# Americano                                           Animated parrot adventure has cartoon action, ...
# Bambi                                                         Disney's original circle-of-life story.
# Ozzy: The Fast and Furriest                         Potty humor, bullying, dark tone in animated d...
# The Swan Princess: Royally Undercover                Brave young princess saves the day; some scares.
# Robo-Dog: Airborne                                   Poorly made family comedy sequel has mild peril.
# The Eagle Huntress                                  Inspiring documentary about barrier-breaking t...
# Pinocchio                                           Disney masterpiece is darker than you may reme...
# Tini: The New Life of Violetta                      Dreadful musical adventure is nonsensical and ...
# Disneynature: Expedition China                      Gentle docu about how crews capture footage of...
# Dolly Parton's Christmas of Many Colors: Circle...  Lots of plot packed into tale of faith and hol...
# Growing Up Wild                                     Intimate look at baby wildlife; some violence,...
# Arlo the Burping Pig                                Predictable story about a girl and the piglet ...
# Motu Patlu: King of Kings                           Friends save the jungle in animated tale; lots...
# Wild Kratts: A Creature Christmas                   Zoologist brothers spread merriment in rescue ...
# A Boy Named Charlie Brown                           Classic Peanuts film is as charming and releva...
# Snoopy, Come Home                                   Adventure-filled Peanuts journey has some sad ...
# ...                                                                                               ...
# The Jungle Book: Mowgli's Story                     Clunky jungle sequel has loss of parent and so...
# The Real Macaw                                      Silly boy-and-his-pet adventure has some peril...
# A Little Princess                                   Wonderful adaptation of classic book; some sca...
# Oliver!                                              Glorious musical based on Dickens' Oliver Twist.
# The Return of Jafar                                    A genie that should have stayed in the bottle.
# Kids for Character                                  TV figures explain concepts like trust and car...
# Animal Crackers                                          Beloved but creaky Marx Brothers comedy hit.
# FernGully 2: The Magical Rescue                     Bland sequel lacks original's star power; some...
# The Secret of NIMH 2: Timmy to the Rescue           Sequel is tamer, more predicable than the clas...
# Babe                                                Heartwarming farm story is touching and a bit ...
# George Balanchine's The Nutcracker                  Macaulay Culkin v. Mouse King in NYC Ballet tr...
# Darby O'Gill and the Little People                   Imaginative story will draw tweens and teens in.
# Herbie Rides Again                                    Kids will love this gentle, slapstick love bug.
# The Pebble and the Penguin                             Animated penguin tale heavy on romance, peril.
# The Adventures of Milo and Otis                     Lovable pet tale about friendship despite diff...
# The Magic of the Golden Bear: Goldy III             Run-of-the-mill kid-meets-wild-animal tale wit...
# The Secret of NIMH                                  Fascinating, but very dark with some creepy im...
# Homeward Bound: The Incredible Journey                Adventurous animal tale will have kids riveted.
# Jetsons: The Movie                                     Great visuals, lackluster characters and plot.
# The Phantom Tollbooth                               Clever artistry fails to convey the book's depth.
# 2001: A Space Odyssey                                 Kubrick's sci-fi masterpiece is still relevant.
# Babar: The Movie                                          Animated elephant adventure has some peril.
# Hansel and Gretel                                   Scary witch may be too intense for very young ...
# ...
# ...                                                          ...
# The Jungle Book: Mowgli's Story                                0
# The Real Macaw                                                 0
# A Little Princess                                              0
# Oliver!                                                        0
# The Return of Jafar                                            0
# Kids for Character                                             0
# Animal Crackers                                                0
# FernGully 2: The Magical Rescue                                0
# The Secret of NIMH 2: Timmy to the Rescue                      0
# Babe                                                           0
# George Balanchine's The Nutcracker                             0
# Darby O'Gill and the Little People                             0
# Herbie Rides Again                                             0
# The Pebble and the Penguin                                     0
# The Adventures of Milo and Otis                                0
# The Magic of the Golden Bear: Goldy III                        0
# The Secret of NIMH                                             0
# Homeward Bound: The Incredible Journey                         0
# Jetsons: The Movie                                             0
# The Phantom Tollbooth                                          0
# 2001: A Space Odyssey                                          0
# Babar: The Movie                                               0
# Hansel and Gretel                                              0
# The New Adventures of Pippi Longstocking                       0
# The Man from Button Willow                                     0
# The Frog Prince                                                0
# The Life and Adventures of Santa Claus (1985)                  0
# The Strongest Man in the World                                 0
# Tales of Beatrix Potter                                        0
# Tintin: The Calculus Affair                                    0
#
#                                                     is_educational  \
# title
# Alex &amp; Me                                                    1
# Daphne &amp; Velma                                               1
# Pup Star: World Tour                                             1
# Pandas                                                           1
# Ladies First                                                     0
# Benji                                                            1
# Earth: One Amazing Day                                           1
# 48 Christmas Wishes                                              1
# All I Want for Christmas Is You                                  1
# Cars 3                                                           1
# Spookley the Square Pumpkin                                      1
# Ghost of the Mountains                                           1
# Born in China                                                    1
# The Horse Dancer                                                 0
# Americano                                                        1
# Bambi                                                            1
# Ozzy: The Fast and Furriest                                      0
# The Swan Princess: Royally Undercover                            1
# Robo-Dog: Airborne                                               1
# The Eagle Huntress                                               1
# Pinocchio                                                        0
# Tini: The New Life of Violetta                                   0
# Disneynature: Expedition China                                   1
# Dolly Parton's Christmas of Many Colors: Circle...               1
# Growing Up Wild                                                  1
# Arlo the Burping Pig                                             1
# Motu Patlu: King of Kings                                        1
# Wild Kratts: A Creature Christmas                                1
# A Boy Named Charlie Brown                                        1
# Snoopy, Come Home                                                1
# ...                                                            ...
# The Jungle Book: Mowgli's Story                                  1
# The Real Macaw                                                   1
# A Little Princess                                                0
# Oliver!                                                          1
# The Return of Jafar                                              0
# Kids for Character                                               0
# Animal Crackers                                                  0
# FernGully 2: The Magical Rescue                                  1
# The Secret of NIMH 2: Timmy to the Rescue                        0
# Babe                                                             1
# George Balanchine's The Nutcracker                               0
# Darby O'Gill and the Little People                               0
# Herbie Rides Again                                               0
# The Pebble and the Penguin                                       0
# The Adventures of Milo and Otis                                  1
# The Magic of the Golden Bear: Goldy III                          1
# The Secret of NIMH                                               1
# Homeward Bound: The Incredible Journey                           1
# Jetsons: The Movie                                               0
# The Phantom Tollbooth                                            0
# 2001: A Space Odyssey                                            0
# Babar: The Movie                                                 1
# Hansel and Gretel                                                1
# The New Adventures of Pippi Longstocking                         1
# The Man from Button Willow                                       1
# The Frog Prince                                                  1
# The Life and Adventures of Santa Claus (1985)                    1
# The Strongest Man in the World                                   0
# Tales of Beatrix Potter                                          1
# Tintin: The Calculus Affair                                      0
#
#                                                     has_Sexy_Stuff  \
# title
# Alex &amp; Me                                                    1
# Daphne &amp; Velma                                               1
# Pup Star: World Tour                                             1
# Pandas                                                           1
# Ladies First                                                     0
# Benji                                                            1
# Earth: One Amazing Day                                           1
# 48 Christmas Wishes                                              0
# All I Want for Christmas Is You                                  1
# Cars 3                                                           1
# Spookley the Square Pumpkin                                      1
# Ghost of the Mountains                                           1
# Born in China                                                    1
# The Horse Dancer                                                 0
# Americano                                                        1
# Bambi                                                            1
# Ozzy: The Fast and Furriest                                      0
# The Swan Princess: Royally Undercover                            1
# Robo-Dog: Airborne                                               1
# The Eagle Huntress                                               1
# Pinocchio                                                        1
# Tini: The New Life of Violetta                                   1
# Disneynature: Expedition China                                   1
# Dolly Parton's Christmas of Many Colors: Circle...               1
# Growing Up Wild                                                  1
# Arlo the Burping Pig                                             1
# Motu Patlu: King of Kings                                        1
# Wild Kratts: A Creature Christmas                                1
# A Boy Named Charlie Brown                                        1
# Snoopy, Come Home                                                1
# ...                                                            ...
# The Jungle Book: Mowgli's Story                                  1
# The Real Macaw                                                   1
# A Little Princess                                                1
# Oliver!                                                          1
# The Return of Jafar                                              1
# Kids for Character                                               1
# Animal Crackers                                                  1
# FernGully 2: The Magical Rescue                                  1
# The Secret of NIMH 2: Timmy to the Rescue                        1
# Babe                                                             1
# George Balanchine's The Nutcracker                               1
# Darby O'Gill and the Little People                               1
# Herbie Rides Again                                               1
# The Pebble and the Penguin                                       1
# The Adventures of Milo and Otis                                  1
# The Magic of the Golden Bear: Goldy III                          1
# The Secret of NIMH                                               1
# Homeward Bound: The Incredible Journey                           1
# Jetsons: The Movie                                               1
# The Phantom Tollbooth                                            1
# 2001: A Space Odyssey                                            0
# Babar: The Movie                                                 1
# Hansel and Gretel                                                1
# The New Adventures of Pippi Longstocking                         1
# The Man from Button Willow                                       1
# The Frog Prince                                                  1
# The Life and Adventures of Santa Claus (1985)                    1
# The Strongest Man in the World                                   1
# Tales of Beatrix Potter                                          1
# Tintin: The Calculus Affair                                      0
#
#                                                     has_Violence_&_Scariness
# title
# Alex &amp; Me                                                              1
# Daphne &amp; Velma                                                         1
# Pup Star: World Tour                                                       1
# Pandas                                                                     1
# Ladies First                                                               0
# Benji                                                                      1
# Earth: One Amazing Day                                                     1
# 48 Christmas Wishes                                                        1
# All I Want for Christmas Is You                                            1
# Cars 3                                                                     1
# Spookley the Square Pumpkin                                                1
# Ghost of the Mountains                                                     1
# Born in China                                                              1
# The Horse Dancer                                                           0
# Americano                                                                  1
# Bambi                                                                      1
# Ozzy: The Fast and Furriest                                                0
# The Swan Princess: Royally Undercover                                      1
# Robo-Dog: Airborne                                                         1
# The Eagle Huntress                                                         1
# Pinocchio                                                                  1
# Tini: The New Life of Violetta                                             1
# Disneynature: Expedition China                                             1
# Dolly Parton's Christmas of Many Colors: Circle...                         1
# Growing Up Wild                                                            1
# Arlo the Burping Pig                                                       1
# Motu Patlu: King of Kings                                                  1
# Wild Kratts: A Creature Christmas                                          1
# A Boy Named Charlie Brown                                                  1
# Snoopy, Come Home                                                          1
# ...                                                                      ...
# The Jungle Book: Mowgli's Story                                            1
# The Real Macaw                                                             1
# A Little Princess                                                          1
# Oliver!                                                                    1
# The Return of Jafar                                                        1
# Kids for Character                                                         1
# Animal Crackers                                                            1
# FernGully 2: The Magical Rescue                                            1
# The Secret of NIMH 2: Timmy to the Rescue                                  1
# Babe                                                                       1
# George Balanchine's The Nutcracker                                         1
# Darby O'Gill and the Little People                                         1
# Herbie Rides Again                                                         1
# The Pebble and the Penguin                                                 1
# The Adventures of Milo and Otis                                            1
# The Magic of the Golden Bear: Goldy III                                    1
# The Secret of NIMH                                                         1
# Homeward Bound: The Incredible Journey                                     1
# Jetsons: The Movie                                                         1
# The Phantom Tollbooth                                                      1
# 2001: A Space Odyssey                                                      0
# Babar: The Movie                                                           1
# Hansel and Gretel                                                          1
# The New Adventures of Pippi Longstocking                                   1
# The Man from Button Willow                                                 1
# The Frog Prince                                                            1
# The Life and Adventures of Santa Claus (1985)                              1
# The Strongest Man in the World                                             1
# Tales of Beatrix Potter                                                    1
# Tintin: The Calculus Affair                                                0
#
# [606 rows x 20 columns]

# %%
df.head()
# Out:
#                              Consumerism  Drinking, Drugs & Smoking  \
# title
# Sicario: Day of the Soldado          0.0                        3.0
# Damsel                               0.0                        3.0
# Distorted                            0.0                        2.0
# The Catcher Was a Spy                0.0                        1.0
# Boundaries                           0.0                        4.0
#
#                              Educational Value  Language MPAA_rating  \
# title
# Sicario: Day of the Soldado                NaN       4.0           R
# Damsel                                     NaN       4.0           R
# Distorted                                  NaN       0.0           R
# The Catcher Was a Spy                      NaN       3.0           R
# Boundaries                                 NaN       4.0           R
#
#                              Positive Messages  Sex  Sexy Stuff  Violence  \
# title
# Sicario: Day of the Soldado                1.0  0.0         NaN       4.0
# Damsel                                     0.0  3.0         NaN       4.0
# Distorted                                  1.0  0.0         NaN       3.0
# The Catcher Was a Spy                      3.0  2.0         NaN       3.0
# Boundaries                                 1.0  4.0         NaN       2.0
#
#                              Violence & Scariness  age     genre  movie_id  \
# title
# Sicario: Day of the Soldado                   NaN   17  Thriller         0
# Damsel                                        NaN   16   Western         1
# Distorted                                     NaN   15  Thriller         2
# The Catcher Was a Spy                         NaN   15  Thriller         3
# Boundaries                                    NaN   16    Comedy         4
#
#                                                           one_line_description  \
# title
# Sicario: Day of the Soldado  Solid drug war sequel has intense violence, la...
# Damsel                       Unusual, uneven Western has violence, language...
# Distorted                    Rapid-fire disturbing images in paranoid thril...
# The Catcher Was a Spy        Well-made spy thriller has some war violence, ...
# Boundaries                    Indie road-trip dramedy has pot dealing/smoking.
#
#                              overall_rating                        slug  \
# title
# Sicario: Day of the Soldado               3  sicario-day-of-the-soldado
# Damsel                                    3                      damsel
# Distorted                                 2                   distorted
# The Catcher Was a Spy                     4       the-catcher-was-a-spy
# Boundaries                                2                  boundaries
#
#                              MPAA_ordinal  is_educational  has_Sexy_Stuff  \
# title
# Sicario: Day of the Soldado             3               0               0
# Damsel                                  3               0               0
# Distorted                               3               0               0
# The Catcher Was a Spy                   3               0               0
# Boundaries                              3               0               0
#
#                              has_Violence_&_Scariness
# title
# Sicario: Day of the Soldado                         0
# Damsel                                              0
# Distorted                                           0
# The Catcher Was a Spy                               0
# Boundaries                                          0

# %%
get_parent_ratings_first()
# Out:
# Welcome to MovieRec4Parents! Let me ask you a few questions before we begin.
# How many children do you have?1
# How old is your child 1 ?
# 7
# Thank you!
# I have just 9 more questions for you. Respond with a ? if you'd like some examples.
# Do you want to see an educational movie?
# Please enter y, n, or ?n
# What amount of "sexy stuff" is okay for your kids, on a scale of 0 to 3?)
# Please enter 0, 1, 2, 3, or ?2
# What level of violence and cartoon scariness is okay for your kids? (0 to 4)
# Please enter 0, 1, 2, 3, 4, or ?3
# What level of exposure to consumerism is okay for your kids? (0 to 5)
# Please enter 0, 1, 2, 3, 4, 5, or ?3
# What level of drinking, drugs, & smoking is okay for your kids? (0 to 5)
# Please enter 0, 1, 2, 3, 4, 5, or ?3
# What level of bad language is okay for your kids? (0 to 5)
# Please enter 0, 1, 2, 3, 4, 5, or ?3
# How important are positive messages in movies to you and kids? (0 to 5)
# Please enter 0, 1, 2, 3, 4, 5, or ?3
# What genre of movie are you interested in seeing?
# Please enter Drama, Family and Kids, Comedy, Action/Adventure, Documentary, Thriller,
# Horror, Science Fiction, Fantasy, Romance, Musical, Classic, Western, or ?Family and Kids
# Finally, what MPAA rating is the most extreme for your kids (G, PG, PG-13, R, or NR (not rated)?)
# Please enter G, PG, PG-13, R, NR (not rated), NC-17, or ?PG-13
# Thank you!
# Give me a movie title and I'll give you five titles you might also like:Antboy 3
# Thanks! Here are my recommendations, along with review text similarity scores:
# ['Underdog',
#  'The Ant Bully',
#  'The Secret of NIMH 2: Timmy to the Rescue',
#  'Stuart Little 3: Call of the Wild',
#  'The Black Stallion']
